# %%
import pandas as pnd #para manejar el dataframe
import numpy as np #para abrir el csv
import matplotlib.pyplot as plt #para graficar 
import sklearn as sk #para normalizar los datos
from sklearn.cluster import KMeans

# %%
X = pnd.read_csv("viviendas_2015_clusters.csv")
X.head()
# Out:
#    Unnamed: 0  VIV_SEL  P1_1  P1_2  P1_3  P1_4  P1_5_1  P1_5_2  P2_1  P2_2  \
# 0           0        5     2     1     1     1       1       1     4     1
# 1           1        1     3     1     1     1       1       1     7     1
# 2           2        3     3     1     1     1       1       1     8     1
# 3           3        4     3     1     1     1       1       1     5     1
# 4           4        5     3     1     1     1       1       1     6     1
#
#    P2_3  cve_est  cve_mun  Cluster
# 0     1        1        1        2
# 1     1        1        1        2
# 2     1        1        1        2
# 3     1        1        1        2
# 4     1        1        1        2

# %%
X.drop('Unnamed: 0', 1, inplace=True)

# %%
X.cve_mun.value_counts()
# Out:
# 4      4104
# 1      3944
# 5      3805
# 2      3546
# 3      2996
# 17     2784
# 30     2717
# 6      2709
# 20     2153
# 7      2110
# 10     1681
# 14     1653
# 39     1612
# 101    1598
# 53     1541
# 19     1524
# 114    1513
# 28     1462
# 48     1280
# 8      1255
# 50     1230
# 9      1180
# 11     1161
# 18     1130
# 193    1063
# 35      996
# 106     971
# 38      880
# 67      843
# 12      828
#        ...
# 317      18
# 198      18
# 217      18
# 207      18
# 533      18
# 401      18
# 520      18
# 210      18
# 142      17
# 190      17
# 160      17
# 513      17
# 278      17
# 234      17
# 166      16
# 211      16
# 128      16
# 202      16
# 64       16
# 346      15
# 327      15
# 88       14
# 422      13
# 403      10
# 227       9
# 136       9
# 519       5
# 135       5
# 175       4
# 138       4
# Name: cve_mun, dtype: int64

# %%
X.Cluster.value_counts()
# Out:
# 3    26341
# 1    20369
# 0    20250
# 2    11446
# Name: Cluster, dtype: int64

# %%
df_mun = X.groupby(['cve_est','cve_mun']).Cluster.apply(lambda x: x.mode())

# %%
df_mun
# Out:
# cve_est  cve_mun
# 1        1        0    2
#          2        0    2
#          3        0    2
#          4        0    2
#          5        0    2
#          6        0    2
#          7        0    2
#          9        0    2
#          10       0    2
#          11       0    2
# 2        1        0    2
#          2        0    2
#          3        0    2
#          4        0    2
#          5        0    2
# 3        1        0    2
#          2        0    2
#          3        0    2
#          8        0    2
#          9        0    2
# 4        1        0    2
#          2        0    2
#          3        0    2
#          4        0    2
#          5        0    2
#          6        0    2
#          9        0    2
#          10       0    2
#          11       0    2
# 5        2        0    2
#                       ..
# 31       106      0    3
# 32       5        0    1
#          7        0    1
#          8        0    1
#          10       0    1
# ...

# %%
d = pnd.DataFrame(df_mun)

# %%
d
# Out:
#                    Cluster
# cve_est cve_mun
# 1       1       0        2
#         2       0        2
#         3       0        2
#         4       0        2
#         5       0        2
#         6       0        2
#         7       0        2
#         9       0        2
#         10      0        2
#         11      0        2
# 2       1       0        2
#         2       0        2
#         3       0        2
#         4       0        2
#         5       0        2
# 3       1       0        2
#         2       0        2
#         3       0        2
#         8       0        2
#         9       0        2
# 4       1       0        2
#         2       0        2
#         3       0        2
#         4       0        2
#         5       0        2
#         6       0        2
#         9       0        2
#         10      0        2
#         11      0        2
# 5       2       0        2
# ...                    ...
# 31      106     0        3
# ...

# %%
d.to_csv('clusters.csv')

# %%
clus = pnd.read_csv('clusters.csv')
clus.head()
# Out:
#    cve_est  cve_mun  Unnamed: 2  Cluster
# 0        1        1           0        2
# 1        1        2           0        2
# 2        1        3           0        2
# 3        1        4           0        2
# 4        1        5           0        2

# %%
clus.drop('Unnamed: 2',1, inplace=True)

# %%
clus.head()
# Out:
#    cve_est  cve_mun  Cluster
# 0        1        1        2
# 1        1        2        2
# 2        1        3        2
# 3        1        4        2
# 4        1        5        2

# %% [markdown]
# ## Leémos el dataset general

# %%
df_general = pnd.read_csv('incidenciaMunicipal_2015_clean_cat.csv')
df_general.head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        6        15           16      4        3      0
# 1        1        1        6        15           17      9       10     10
# 2        1        1        6        15           18      4        1      5
# 3        1        1        6        15           19      0        0      0
# 4        1        1        6        15           20     34       32     46
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0      7     4      6      4       3           4        1          4
# 1     11    11      6     10      18           8        3         14
# 2      3     0      1      1       4           2        5          6
# 3      0     1      0      0       0           0        0          1
# 4     44    49     34     49      56          34       24         49
#
#    DICIEMBRE  TOTAL_DELITOS
# 0          7             43
# 1         14            115
# ...

# %%
df_general['VIVIENDA_ENDITUH'] = 99

# %%
df_general.head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        6        15           16      4        3      0
# 1        1        1        6        15           17      9       10     10
# 2        1        1        6        15           18      4        1      5
# 3        1        1        6        15           19      0        0      0
# 4        1        1        6        15           20     34       32     46
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0      7     4      6      4       3           4        1          4
# 1     11    11      6     10      18           8        3         14
# 2      3     0      1      1       4           2        5          6
# 3      0     1      0      0       0           0        0          1
# 4     44    49     34     49      56          34       24         49
#
#    DICIEMBRE  TOTAL_DELITOS  VIVIENDA_ENDUTIH  VIVIENDA_ENDITUH
# ...

# %%
df1 =  df_general[['CVE_ENT','CVE_MUN','VIVIENDA_ENDITUH']]

# %%
cont = 0
for row in df1.iterrows():
    cont2 = 0
    for row2 in clus.iterrows():
        if df1.CVE_ENT[cont] == clus.cve_est[cont2] and df1.CVE_MUN[cont] == clus.cve_mun[cont2]:
            df1.VIVIENDA_ENDITUH[cont] = clus.Cluster[cont2]
        cont2 = cont2+1
    cont = cont+1
    print(cont2)
print(cont)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 125004
# 20

# %%
df1
# Out:
#         CVE_ENT  CVE_MUN  VIVIENDA_ENDITUH
# 0             1        1                 2
# 1             1        1                 2
# 2             1        1                 2
# 3             1        1                 2
# 4             1        1                 2
# 5             1        1                 2
# 6             1        1                 2
# 7             1        1                 2
# 8             1        1                 2
# 9             1        1                 2
# 10            1        1                 2
# 11            1        1                 2
# 12            1        1                 2
# 13            1        1                 2
# 14            1        1                 2
# 15            1        1                 2
# 16            1        1                 2
# 17            1        1                 2
# 18            1        1                 2
# 19            1        1                 2
# 20            1        1                 2
# ...

# %%
df_general['VIVIENDA_ENDUTIH'] = df1.VIVIENDA_ENDITUH

# %%
df_general.drop('VIVIENDA_ENDITUH',1,inplace=True)

# %%
df_general.head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        6        15           16      4        3      0
# 1        1        1        6        15           17      9       10     10
# 2        1        1        6        15           18      4        1      5
# 3        1        1        6        15           19      0        0      0
# 4        1        1        6        15           20     34       32     46
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0      7     4      6      4       3           4        1          4
# 1     11    11      6     10      18           8        3         14
# 2      3     0      1      1       4           2        5          6
# 3      0     1      0      0       0           0        0          1
# 4     44    49     34     49      56          34       24         49
#
#    DICIEMBRE  TOTAL_DELITOS  VIVIENDA_ENDUTIH
# 0          7             43                 2
# ...

# %%
df_general.to_csv('asdfasdf.csv')

# %%
np.unique(df_general.VIVIENDA_ENDUTIH)
# Out:
# array([ 2, 99], dtype=int64)
